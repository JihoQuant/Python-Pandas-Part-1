# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import FinanceDataReader as fdr

from pandas import DataFrame, Series
from initializer import init

# %matplotlib inline
plt.rcParams['font.family'] = 'AppleGothic'
mpl.rcParams['axes.unicode_minus'] = False

init()

# %%
df: DataFrame = fdr.DataReader("005930", "2009-09-01", "2010-12-31").drop("Change", axis=1)
df.tail()
# Out:
#              Open   High    Low  Close  Volume
# Date
# 2010-12-24  18780  18780  18500  18500  169733
# 2010-12-27  18500  18600  18300  18440  210673
# 2010-12-28  18560  19000  18520  18760  313323
# 2010-12-29  18700  19020  18640  18900  238527
# 2010-12-30  18840  19040  18840  18980  183831

# %% [markdown]
# > index는 DateTimeIndex type이고 sorting 되어야 함

# %%
sample = df.iloc[:3]
sample
# Out:
#              Open   High    Low  Close  Volume
# Date
# 2009-09-01  15600  16000  15340  15980  511854
# 2009-09-02  15699  15820  15600  15680  558282
# 2009-09-03  15660  15700  15480  15500  321269

# %% [markdown]
# # 1. `asfreq()`
#
# - sampling 대상 index에 mapping 되어 있는 value는 그대로 유지

# %%
sample.asfreq("H")
# Out:
#                          Open      High       Low     Close     Volume
# Date
# 2009-09-01 00:00:00 15600.000 16000.000 15340.000 15980.000 511854.000
# 2009-09-01 01:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 02:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 03:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 04:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 05:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 06:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 07:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 08:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 09:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 10:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 11:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 12:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 13:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 14:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 15:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 16:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 17:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 18:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 19:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 20:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 21:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 22:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 23:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 00:00:00 15699.000 15820.000 15600.000 15680.000 558282.000
# 2009-09-02 01:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 02:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 03:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 04:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 05:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 06:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 07:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 08:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 09:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 10:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 11:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 12:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 13:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 14:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 15:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 16:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 17:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 18:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 19:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 20:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 21:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 22:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-02 23:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-03 00:00:00 15660.000 15700.000 15480.000 15500.000 321269.000

# %%
sample.asfreq("H", method="ffill").head()
# Out:
#                       Open   High    Low  Close  Volume
# Date
# 2009-09-01 00:00:00  15600  16000  15340  15980  511854
# 2009-09-01 01:00:00  15600  16000  15340  15980  511854
# 2009-09-01 02:00:00  15600  16000  15340  15980  511854
# 2009-09-01 03:00:00  15600  16000  15340  15980  511854
# 2009-09-01 04:00:00  15600  16000  15340  15980  511854

# %%
sample.asfreq("M")
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume]
# Index: []

# %%
"""월 말일이 거래일이 아닐 경우 다음과 같이 NaN으로 값이 채워짐"""
df.asfreq("M")
# Out:
# '월 말일이 거래일이 아닐 경우 다음과 같이 NaN으로 값이 채워짐'
#                 Open      High       Low     Close     Volume
# Date
# 2009-09-30 16140.000 16500.000 16120.000 16300.000 479813.000
# 2009-10-31       NaN       NaN       NaN       NaN        NaN
# 2009-11-30 14460.000 14640.000 14380.000 14400.000 376335.000
# 2009-12-31       NaN       NaN       NaN       NaN        NaN
# 2010-01-31       NaN       NaN       NaN       NaN        NaN
# 2010-02-28       NaN       NaN       NaN       NaN        NaN
# 2010-03-31 16280.000 16680.000 16260.000 16360.000 434300.000
# 2010-04-30 16560.000 17040.000 16540.000 16980.000 454668.000
# 2010-05-31 15440.000 15620.000 15360.000 15520.000 255822.000
# 2010-06-30 15399.000 15600.000 15399.000 15480.000 536406.000
# 2010-07-31       NaN       NaN       NaN       NaN        NaN
# 2010-08-31 15320.000 15439.000 15119.000 15120.000 441643.000
# 2010-09-30 15440.000 15580.000 15340.000 15540.000 337258.000
# 2010-10-31       NaN       NaN       NaN       NaN        NaN
# 2010-11-30 16640.000 16920.000 16520.000 16520.000 424616.000

# %% [markdown]
# # 2. `resample()`
#
# - (date)time-based groupby
# - aggregation function과 같이 쓰인다.
# - 사실 `asfreq()`는 잘 사용하지 않는다.

# %%
close_df = df[["Close"]]
log_rtn_df: DataFrame = np.log(close_df / close_df.shift(1)).fillna(0)

log_rtn_df.head()
# Out:
#             Close
# Date
# 2009-09-01  0.000
# 2009-09-02 -0.019
# 2009-09-03 -0.012
# 2009-09-04 -0.010
# 2009-09-07  0.008

# %%
log_rtn_df.resample("M")

# %%
"""resample의 단점 - 데이터 내 연말의 값을 대표값으로 설정해버림"""
"""그래도 날짜는 Business Day 여부 상관없이 12월 31일로 고정함"""

log_rtn_df.resample("A").last() # Annual

"""2009-12-30 value 확인"""
log_rtn_df.loc["2009-12-27":]
# Out:
# 'resample의 단점 - 데이터 내 연말의 값을 대표값으로 설정해버림'
# '그래도 날짜는 Business Day 여부 상관없이 12월 31일로 고정함'
#             Close
# Date
# 2009-12-31  0.016
# 2010-12-31  0.004
# '2009-12-30 value 확인'
#             Close
# Date
# 2009-12-28 -0.004
# 2009-12-29 -0.001
# 2009-12-30  0.016
# 2010-01-04  0.012
# 2010-01-05  0.016
# ...           ...
# 2010-12-24 -0.012
# 2010-12-27 -0.003
# 2010-12-28  0.017
# 2010-12-29  0.007
# 2010-12-30  0.004
#
# [254 rows x 1 columns]

# %%
"""사실 이렇게 쓸 일은 없지만, 작동 방식을 보는 것으로 하자."""
log_rtn_df.resample("H").mean().head()
log_rtn_df.resample("H").agg({"Close": "mean"}).head()
# Out:
# '사실 이렇게 쓸 일은 없지만, 작동 방식을 보는 것으로 하자.'
#                      Close
# Date
# 2009-09-01 00:00:00  0.000
# 2009-09-01 01:00:00    NaN
# 2009-09-01 02:00:00    NaN
# 2009-09-01 03:00:00    NaN
# 2009-09-01 04:00:00    NaN
#                      Close
# Date
# 2009-09-01 00:00:00  0.000
# 2009-09-01 01:00:00    NaN
# 2009-09-01 02:00:00    NaN
# 2009-09-01 03:00:00    NaN
# 2009-09-01 04:00:00    NaN

# %% [markdown]
# ## 2.1. Upsampling & Downsampling

# %%
by_hour = sample.resample("H").mean()
by_hour.head()
# Out:
#                          Open      High       Low     Close     Volume
# Date
# 2009-09-01 00:00:00 15600.000 16000.000 15340.000 15980.000 511854.000
# 2009-09-01 01:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 02:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 03:00:00       NaN       NaN       NaN       NaN        NaN
# 2009-09-01 04:00:00       NaN       NaN       NaN       NaN        NaN

# %%
"""Downsampling"""
sample.resample("A").mean()
# Out:
# 'Downsampling'
#                 Open      High       Low     Close     Volume
# Date
# 2009-12-31 15653.000 15840.000 15473.333 15720.000 463801.667

# %% [markdown]
# ### 2.1.1. Filling `NaN`
#
# 1. `fillna`: `bfill`, `ffill`
# 2. `interploate()`: linear interploation

# %%
"""이전 값으로 NaN 채우기"""
by_hour.fillna(method="ffill").head()
# Out:
# '이전 값으로 NaN 채우기'
#                          Open      High       Low     Close     Volume
# Date
# 2009-09-01 00:00:00 15600.000 16000.000 15340.000 15980.000 511854.000
# 2009-09-01 01:00:00 15600.000 16000.000 15340.000 15980.000 511854.000
# 2009-09-01 02:00:00 15600.000 16000.000 15340.000 15980.000 511854.000
# 2009-09-01 03:00:00 15600.000 16000.000 15340.000 15980.000 511854.000
# 2009-09-01 04:00:00 15600.000 16000.000 15340.000 15980.000 511854.000

# %%
"""interpolate() - NaN 양 끝 데이터를 등분해서 값을 채움"""
"""[1, NaN, NaN, 4] 라고 할 때 [1, 2, 3, 4]로 만듦"""
by_hour.interpolate().head()

"""실제로 값 차이가 동일한지 확인하려면 - (df - df.shift(1)) or diff()"""
by_hour.interpolate().diff().head()
# Out:
# 'interpolate() - NaN 양 끝 데이터를 등분해서 값을 채움'
# '[1, NaN, NaN, 4] 라고 할 때 [1, 2, 3, 4]로 만듦'
#                          Open      High       Low     Close     Volume
# Date
# 2009-09-01 00:00:00 15600.000 16000.000 15340.000 15980.000 511854.000
# 2009-09-01 01:00:00 15604.125 15992.500 15350.833 15967.500 513788.500
# 2009-09-01 02:00:00 15608.250 15985.000 15361.667 15955.000 515723.000
# 2009-09-01 03:00:00 15612.375 15977.500 15372.500 15942.500 517657.500
# 2009-09-01 04:00:00 15616.500 15970.000 15383.333 15930.000 519592.000
# '실제로 값 차이가 동일한지 확인하려면 - (df - df.shift(1)) or diff()'
#                      Open   High    Low   Close   Volume
# Date
# 2009-09-01 00:00:00   NaN    NaN    NaN     NaN      NaN
# 2009-09-01 01:00:00 4.125 -7.500 10.833 -12.500 1934.500
# 2009-09-01 02:00:00 4.125 -7.500 10.833 -12.500 1934.500
# 2009-09-01 03:00:00 4.125 -7.500 10.833 -12.500 1934.500
# 2009-09-01 04:00:00 4.125 -7.500 10.833 -12.500 1934.500

# %% [markdown]
# ## 2.2. `kind` argument

# %%
"""인덱스의 종류를 지정한다"""
"""Period"""
df.resample("M", kind="period").mean()
"""Monthly Last Day"""
df.resample("M", kind="timestamp").mean()
# Out:
# '인덱스의 종류를 지정한다'
# 'Period'
#              Open      High       Low     Close     Volume
# Date
# 2009-09 15814.455 16009.955 15633.455 15865.455 464460.273
# 2009-10 14999.857 15171.143 14721.762 14897.143 533470.381
# 2009-11 14692.952 14838.095 14507.476 14651.429 374873.143
# 2009-12 15435.952 15590.381 15321.524 15496.190 334084.905
# 2010-01 16438.000 16607.900 16199.000 16402.000 378501.050
# 2010-02 15305.053 15399.947 15098.842 15232.632 317400.000
# 2010-03 15844.318 15983.591 15708.136 15853.636 274398.773
# 2010-04 16891.818 17017.273 16688.182 16882.727 332281.682
# 2010-05 15800.895 15932.526 15587.368 15744.211 396018.053
# 2010-06 15964.619 16094.190 15813.238 15953.333 299446.048
# 2010-07 16019.955 16139.045 15860.773 16008.182 329414.955
# 2010-08 15739.955 15841.636 15626.091 15716.364 257033.545
# 2010-09 15329.368 15461.895 15171.421 15306.316 404004.000
# 2010-10 15238.952 15342.762 15092.286 15212.381 391261.476
# 2010-11 15966.182 16148.182 15794.455 15970.000 461218.000
# 2010-12 18179.091 18434.545 18055.455 18292.727 350659.091
# 'Monthly Last Day'
#                 Open      High       Low     Close     Volume
# Date
# 2009-09-30 15814.455 16009.955 15633.455 15865.455 464460.273
# 2009-10-31 14999.857 15171.143 14721.762 14897.143 533470.381
# 2009-11-30 14692.952 14838.095 14507.476 14651.429 374873.143
# 2009-12-31 15435.952 15590.381 15321.524 15496.190 334084.905
# 2010-01-31 16438.000 16607.900 16199.000 16402.000 378501.050
# 2010-02-28 15305.053 15399.947 15098.842 15232.632 317400.000
# 2010-03-31 15844.318 15983.591 15708.136 15853.636 274398.773
# 2010-04-30 16891.818 17017.273 16688.182 16882.727 332281.682
# 2010-05-31 15800.895 15932.526 15587.368 15744.211 396018.053
# 2010-06-30 15964.619 16094.190 15813.238 15953.333 299446.048
# 2010-07-31 16019.955 16139.045 15860.773 16008.182 329414.955
# 2010-08-31 15739.955 15841.636 15626.091 15716.364 257033.545
# 2010-09-30 15329.368 15461.895 15171.421 15306.316 404004.000
# 2010-10-31 15238.952 15342.762 15092.286 15212.381 391261.476
# 2010-11-30 15966.182 16148.182 15794.455 15970.000 461218.000
# 2010-12-31 18179.091 18434.545 18055.455 18292.727 350659.091

# %%
df.resample("M", kind="period").mean().index
df.resample("M", kind="timestamp").mean().index # kind default
# Out:
# PeriodIndex(['2009-09', '2009-10', '2009-11', '2009-12', '2010-01', '2010-02',
#              '2010-03', '2010-04', '2010-05', '2010-06', '2010-07', '2010-08',
#              '2010-09', '2010-10', '2010-11', '2010-12'],
#             dtype='period[M]', name='Date')
# DatetimeIndex(['2009-09-30', '2009-10-31', '2009-11-30', '2009-12-31',
#                '2010-01-31', '2010-02-28', '2010-03-31', '2010-04-30',
#                '2010-05-31', '2010-06-30', '2010-07-31', '2010-08-31',
#                '2010-09-30', '2010-10-31', '2010-11-30', '2010-12-31'],
#               dtype='datetime64[ns]', name='Date', freq='M')

# %% [markdown]
# ## 2.3. `ohlc()`

# %%
"""월봉?!"""
df["Close"].resample("M").ohlc()
# Out:
# '월봉?!'
#              open   high    low  close
# Date
# 2009-09-30  15980  16500  15280  16300
# 2009-10-31  15840  15840  14360  14460
# 2009-11-30  14360  15180  14240  14400
# 2009-12-31  14740  15980  14740  15980
# 2010-01-31  16180  17000  15680  15680
# 2010-02-28  15540  15580  14720  14880
# 2010-03-31  15400  16400  15220  16360
# 2010-04-30  16900  17400  16500  16980
# 2010-05-31  16580  16680  14820  15520
# 2010-06-30  15360  16600  15360  15480
# 2010-07-31  15320  16740  15320  16200
# 2010-08-31  16200  16300  15120  15120
# 2010-09-30  15040  15760  14900  15540
# 2010-10-31  15540  15860  14820  14900
# 2010-11-30  14940  17020  14800  16520
# 2010-12-31  16400  18980  16400  18980

# %% [markdown]
# ## 2.4. vs `asfreq()`

# %%
df.asfreq("M")   # DataFrame
df.resample("M") # Group - DatetimeIndexResampler
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2009-09-30 16140.000 16500.000 16120.000 16300.000 479813.000
# 2009-10-31       NaN       NaN       NaN       NaN        NaN
# 2009-11-30 14460.000 14640.000 14380.000 14400.000 376335.000
# 2009-12-31       NaN       NaN       NaN       NaN        NaN
# 2010-01-31       NaN       NaN       NaN       NaN        NaN
# 2010-02-28       NaN       NaN       NaN       NaN        NaN
# 2010-03-31 16280.000 16680.000 16260.000 16360.000 434300.000
# 2010-04-30 16560.000 17040.000 16540.000 16980.000 454668.000
# 2010-05-31 15440.000 15620.000 15360.000 15520.000 255822.000
# 2010-06-30 15399.000 15600.000 15399.000 15480.000 536406.000
# 2010-07-31       NaN       NaN       NaN       NaN        NaN
# 2010-08-31 15320.000 15439.000 15119.000 15120.000 441643.000
# 2010-09-30 15440.000 15580.000 15340.000 15540.000 337258.000
# 2010-10-31       NaN       NaN       NaN       NaN        NaN
# 2010-11-30 16640.000 16920.000 16520.000 16520.000 424616.000

# %%
df.asfreq("M").head()          # 무조건 월말일
df.resample("M").last().head() # 가장 말일 데이터 - 근데 날짜도 무조건 말일로 고정해버림
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2009-09-30 16140.000 16500.000 16120.000 16300.000 479813.000
# 2009-10-31       NaN       NaN       NaN       NaN        NaN
# 2009-11-30 14460.000 14640.000 14380.000 14400.000 376335.000
# 2009-12-31       NaN       NaN       NaN       NaN        NaN
# 2010-01-31       NaN       NaN       NaN       NaN        NaN
#              Open   High    Low  Close  Volume
# Date
# 2009-09-30  16140  16500  16120  16300  479813
# 2009-10-31  14660  14799  14440  14460  557328
# 2009-11-30  14460  14640  14380  14400  376335
# 2009-12-31  15760  15980  15740  15980  295625
# 2010-01-31  16000  16019  15600  15680  457285

# %%
df.asfreq("M").mean()
df.resample("M").mean()
# Out:
# Open      15742.111
# High      16002.111
# Low       15670.889
# Close     15802.222
# Volume   415651.222
# dtype: float64
#                 Open      High       Low     Close     Volume
# Date
# 2009-09-30 15814.455 16009.955 15633.455 15865.455 464460.273
# 2009-10-31 14999.857 15171.143 14721.762 14897.143 533470.381
# 2009-11-30 14692.952 14838.095 14507.476 14651.429 374873.143
# 2009-12-31 15435.952 15590.381 15321.524 15496.190 334084.905
# 2010-01-31 16438.000 16607.900 16199.000 16402.000 378501.050
# 2010-02-28 15305.053 15399.947 15098.842 15232.632 317400.000
# 2010-03-31 15844.318 15983.591 15708.136 15853.636 274398.773
# 2010-04-30 16891.818 17017.273 16688.182 16882.727 332281.682
# 2010-05-31 15800.895 15932.526 15587.368 15744.211 396018.053
# 2010-06-30 15964.619 16094.190 15813.238 15953.333 299446.048
# 2010-07-31 16019.955 16139.045 15860.773 16008.182 329414.955
# 2010-08-31 15739.955 15841.636 15626.091 15716.364 257033.545
# 2010-09-30 15329.368 15461.895 15171.421 15306.316 404004.000
# 2010-10-31 15238.952 15342.762 15092.286 15212.381 391261.476
# 2010-11-30 15966.182 16148.182 15794.455 15970.000 461218.000
# 2010-12-31 18179.091 18434.545 18055.455 18292.727 350659.091

# %% [markdown]
# # 3. Exercise - 월별 수익률 구하기
#
# - 월마다 발생하는 총수익을 월별로 산출

# %%
pd.set_option("display.float_format", lambda x: "%.5f" % x)

# %% [markdown]
# ## 3.1. Using `resample()`

# %%
log_rtn_df.head()
# Out:
#               Close
# Date
# 2009-09-01  0.00000
# 2009-09-02 -0.01895
# 2009-09-03 -0.01155
# 2009-09-04 -0.01038
# 2009-09-07  0.00779

# %%
"""로그 수익률"""
log_rtn_df.resample("M").sum()
# Out:
# '로그 수익률'
#               Close
# Date
# 2009-09-30  0.01983
# 2009-10-31 -0.11978
# 2009-11-30 -0.00416
# 2009-12-31  0.10411
# 2010-01-31 -0.01895
# 2010-02-28 -0.05237
# 2010-03-31  0.09482
# 2010-04-30  0.03720
# 2010-05-31 -0.08991
# 2010-06-30 -0.00258
# 2010-07-31  0.04546
# 2010-08-31 -0.06899
# 2010-09-30  0.02740
# 2010-10-31 -0.04206
# 2010-11-30  0.10321
# 2010-12-31  0.13881

# %%
"""실제 수익률"""
np.exp(log_rtn_df.resample("M").sum()) - 1
# Out:
# '실제 수익률'
#               Close
# Date
# 2009-09-30  0.02003
# 2009-10-31 -0.11288
# 2009-11-30 -0.00415
# 2009-12-31  0.10972
# 2010-01-31 -0.01877
# 2010-02-28 -0.05102
# 2010-03-31  0.09946
# 2010-04-30  0.03790
# 2010-05-31 -0.08598
# 2010-06-30 -0.00258
# 2010-07-31  0.04651
# 2010-08-31 -0.06667
# 2010-09-30  0.02778
# 2010-10-31 -0.04118
# 2010-11-30  0.10872
# 2010-12-31  0.14891

# %%
"""월별 수익률"""
month_cum_rtn_df: DataFrame = (np.exp(log_rtn_df.resample("M").sum()) - 1)

month_cum_rtn_df.head()
month_cum_rtn_df.loc["2010-01-31"]
# Out:
# '월별 수익률'
#               Close
# Date
# 2009-09-30  0.02003
# 2009-10-31 -0.11288
# 2009-11-30 -0.00415
# 2009-12-31  0.10972
# 2010-01-31 -0.01877
# Close   -0.01877
# Name: 2010-01-31 00:00:00, dtype: float64

# %%
"""10월 31일 데이터가 없어서 30일 데이터로 계산함"""
(df.loc["2009-10-30", "Close"] / df.loc["2009-09-30", "Close"]) - 1

assert round(month_cum_rtn_df.loc["2009-10-31", "Close"], 13) == round((df.loc["2009-10-30", "Close"] / df.loc["2009-09-30", "Close"]) - 1, 13)
# Out:
# '10월 31일 데이터가 없어서 30일 데이터로 계산함'
# -0.1128834355828221

# %% [markdown]
# ## 3.3. `drop_duplicates()`
#
# - 정확하게 "월말 데이터"를 내가 가지고 있는 데이터의 "월 말 날짜"에 가져오기

# %%
df.head()
# Out:
#              Open   High    Low  Close  Volume
# Date
# 2009-09-01  15600  16000  15340  15980  511854
# 2009-09-02  15699  15820  15600  15680  558282
# 2009-09-03  15660  15700  15480  15500  321269
# 2009-09-04  15620  15660  15220  15340  456530
# 2009-09-07  15420  15600  15219  15460  339857

# %%
df["year"] = df.index.year
df["month"] = df.index.month

monthly_df = df.drop_duplicates(subset=["year", "month"], keep="last")
monthly_df = monthly_df.drop(["year", "month"], axis=1)
monthly_df.head()
# Out:
#              Open   High    Low  Close  Volume
# Date
# 2009-09-30  16140  16500  16120  16300  479813
# 2009-10-30  14660  14799  14440  14460  557328
# 2009-11-30  14460  14640  14380  14400  376335
# 2009-12-30  15760  15980  15740  15980  295625
# 2010-01-29  16000  16019  15600  15680  457285

# %%
"""첫 달은 수익률이 0이 되어버리는..."""
monthly_df[["Close"]].pct_change().fillna(0)
# Out:
# '첫 달은 수익률이 0이 되어버리는...'
#               Close
# Date
# 2009-09-30  0.00000
# 2009-10-30 -0.11288
# 2009-11-30 -0.00415
# 2009-12-30  0.10972
# 2010-01-29 -0.01877
# 2010-02-26 -0.05102
# 2010-03-31  0.09946
# 2010-04-30  0.03790
# 2010-05-31 -0.08598
# 2010-06-30 -0.00258
# 2010-07-30  0.04651
# 2010-08-31 -0.06667
# 2010-09-30  0.02778
# 2010-10-29 -0.04118
# 2010-11-30  0.10872
# 2010-12-30  0.14891
